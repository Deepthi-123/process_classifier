# %%
import numpy as np
import pandas
from io import StringIO
import matplotlib.pyplot as plt

# %%
names = ['date', 'time','symbols' ,'eigen_force']
dataset = pandas.read_csv('/home/deepthi/task1_eig/label1_0.log', sep = ',', names = names)

# %%
dataset
# Out:
#                     date  time              symbols  eigen_force
# 0    2017-04-20 10:08:55   228  1492675735228554964    -0.103879
# 1    2017-04-20 10:08:55   287  1492675735287084102     0.089912
# 2    2017-04-20 10:08:55   296  1492675735296185016     0.084076
# 3    2017-04-20 10:08:55   312  1492675735312686920     0.062979
# 4    2017-04-20 10:08:55   328  1492675735328120946     0.090391
# 5    2017-04-20 10:08:55   336  1492675735336384057     0.100043
# 6    2017-04-20 10:08:55   361  1492675735361124038     0.063512
# 7    2017-04-20 10:08:55   369  1492675735369630098     0.069960
# 8    2017-04-20 10:08:55   375  1492675735375870943     0.049353
# 9    2017-04-20 10:08:55   393  1492675735393224000     0.102518
# 10   2017-04-20 10:08:55   401  1492675735401530027     0.128673
# 11   2017-04-20 10:08:55   407  1492675735407181024     0.153809
# 12   2017-04-20 10:08:55   417  1492675735417546987     0.132819
# ...

# %%
dataset['eigen_force'].plot()
